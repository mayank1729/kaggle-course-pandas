# %%
import pandas as pd

# %%
wine_reviews = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0) 
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.price
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
wine_reviews["country"]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: str

# %%
wine_reviews["country"][5]
# Out:
# 'Spain'

# %%
wine_reviews.iloc[10]
# Out:
# country                                                                 US
# description              Soft, supple plum envelopes an oaky structure ...
# designation                                                 Mountain Cuvée
# points                                                                  87
# price                                                                 19.0
# province                                                        California
# region_1                                                       Napa Valley
# region_2                                                              Napa
# taster_name                                                 Virginie Boone
# taster_twitter_handle                                              @vboone
# title                    Kirkland Signature 2011 Mountain Cuvée Caberne...
# variety                                                 Cabernet Sauvignon
# ...

# %%
wine_reviews.iloc[:,:3]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation
# 0                                 Vulkà Bianco
# 1                                     Avidagos
# ...

# %%
wine_reviews.iloc[:5, :3]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation
# 0                        Vulkà Bianco
# 1                            Avidagos
# 2                                 NaN
# 3                Reserve Late Harvest
# 4  Vintner's Reserve Wild Child Block

# %%
wine_reviews.loc[0, "description"]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
wine_reviews.loc[:, ["country", "description"]]
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 2 columns]

# %%
# wine_reviews.set_index("country", inplace= True)
# wine_reviews.head()

# %%
wine_reviews.country == "Italy"
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == "Italy"]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[ (wine_reviews.country == "Italy") & (wine_reviews.points >= 95)]
# Out:
#        country                                        description  \
# 350      Italy  After a few minutes in the glass, this stunnin...
# 361      Italy  Enticing scents of ripe berry, underbrush, gri...
# 1561     Italy  Here's a “wow” wine on every level, with incre...
# 1563     Italy  Recently implemented winemaker and cellar chan...
# 1564     Italy  The 2008 Ornellaia delivers concentrated aroma...
# ...        ...                                                ...
# 125836   Italy  You really can't beat the beauty of this Barol...
# 125845   Italy  An exciting flagship wine from one of the best...
# 125846   Italy  A tiny percentage of Barbera grapes accounts f...
# 125847   Italy  Costa Russi presents a dark wall of ripe fruit...
# 126240   Italy  Ben Ryé is always a fabulous dessert wine from...
#
#              designation  points  price           province  \
# 350      Vignolo Riserva      97  150.0           Piedmont
# ...

# %%
wine_reviews.loc[ (wine_reviews.country == "Italy") | (wine_reviews.points >= 95)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.country.isin(["Italy", "France"])
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country.isin(["Italy", "France"])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.price.notnull()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 129966     True
# 129967     True
# 129968     True
# 129969     True
# 129970     True
# Name: price, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
wine_reviews.price.isnull()
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: price, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.price.isnull()]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %% [markdown]
# ### `isnull()` vs `notnull()` in pandas
#
# Both functions are used to **detect missing values (NaN / None)** in pandas.
#
# ---
#
# #### `isnull()`
#
# - Returns **True where the value is missing**
# - Returns **False where the value exists**
#
# Example:
#
# ```python
# df.isnull()
# ```
#
# | value | result |
# |------|--------|
# | 10 | False |
# | NaN | True |
# | "wine" | False |
#
# So it answers: **"Is this value missing?"**
#
# ---
#
# #### `notnull()`
#
# - Returns **True where the value exists**
# - Returns **False where the value is missing**
#
# Example:
#
# ```python
# df.notnull()
# ```
#
# | value | result |
# |------|--------|
# | 10 | True |
# | NaN | False |
# | "wine" | True |
#
# So it answers: **"Is this value present?"**
#
# ---
#
# #### Relationship
#
# They are exact opposites:
#
# ```python
# df.notnull() == ~df.isnull()
# ```
#
# ---
#
# #### Common usage examples
#
# Filter rows **with missing values**:
#
# ```python
# df[df.price.isnull()]
# ```
#
# Filter rows **without missing values**:
#
# ```python
# df[df.price.notnull()]
# ```
#
# ---
#
# ✅ **Summary**
#
# - `isnull()` → finds **missing values**
# - `notnull()` → finds **non-missing values**

# %%
wine_reviews["critic"] = "Bad"
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# Select the `description` column from `reviews` and assign the result to the variable `desc`.

# %%
desc = wine_reviews["description"]
desc
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: str

# %% [markdown]
# Follow-up question: what type of object is `desc`? If you're not sure, you can check by calling Python's `type` function: `type(desc)`.

# %%
type(desc)
# Out:
# pandas.Series

# %% [markdown]
# ## 2.
#
# Select the first value from the description column of `reviews`, assigning it to variable `first_description`.

# %%
first_description = desc[0]
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %% [markdown]
# ### `loc` vs `iloc` in pandas
#
# The main difference between `loc` and `iloc` is **how rows and columns are selected**.
#
# | Method | Selects by | Uses DataFrame index? |
# |------|------|------|
# | `loc` | **Label-based indexing** | ✅ Yes |
# | `iloc` | **Position-based indexing** | ❌ No (uses integer position) |
#
# ---
#
# ### `loc` → Uses the **actual index labels**
#
# If your DataFrame index looks like this:
#
# ```python
# index: [10, 20, 30]
# ```
#
# Then:
#
# ```python
# df.loc[20]
# ```
#
# selects the row **whose index label is `20`**.
#
# ---
#
# ### `iloc` → Uses **row position (0-based)**
#
# `iloc` ignores the index labels and uses the **row order**.
#
# ```python
# df.iloc[1]
# ```
#
# selects the **second row**, regardless of what the index label is.
#
# ---
#
# ### Example
#
# DataFrame:
#
# | index | country |
# |------|------|
# | 10 | Italy |
# | 20 | France |
# | 30 | Spain |
#
# Using `loc`:
#
# ```python
# df.loc[20]
# ```
#
# ➡ Returns the row with index **20** → France
#
# Using `iloc`:
#
# ```python
# df.iloc[1]
# ```
#
# ➡ Returns the row at **position 1** → France
#
# ---
#
# ### Important difference in slicing
#
# ```python
# df.loc[0:3]   # includes 3
# df.iloc[0:3]  # excludes 3
# ```
#
# - `loc` slicing is **inclusive**
# - `iloc` slicing follows **normal Python slicing (exclusive end)**
#
# ---
#
# ### Quick way to remember
#
# - **`loc` → location by label**
# - **`iloc` → integer location (position)**

# %% [markdown]
# ## 3.
#
# Select the first row of data (the first record) from `reviews`, assigning it to the variable `first_row`.

# %%
first_row = wine_reviews.iloc[0,:]
first_row
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %% [markdown]
# ## 4.
#
# Select the first 10 values from the `description` column in `reviews`, assigning the result to variable `first_descriptions`.
#
# Hint: format your output as a pandas Series.

# %%
first_descriptions = wine_reviews["description"].iloc[:10]
first_descriptions
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# 5    Blackberry and raspberry aromas show a typical...
# 6    Here's a bright, informal red that opens with ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, dtype: str

# %% [markdown]
# ## 5.
#
# Select the records with index labels `1`, `2`, `3`, `5`, and `8`, assigning the result to the variable `sample_reviews`.
#
# In other words, generate the following DataFrame:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/sHZvI1O.png)

# %%
# loc can work with : as well in columns. If you want to specify column, then you need labels instead of indices
sample_reviews = wine_reviews.loc[[1,2,3,5,8], :]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %%
# # loc can work with : as well in columns. If you want to specify column, then you need labels instead of indices
# sample_reviews = wine_reviews.loc[[1,2,3,5,8], :2] # Will give error
# sample_reviews

# %% [markdown]
# ## 6.
#
# Create a variable `df` containing the `country`, `province`, `region_1`, and `region_2` columns of the records with the index labels `0`, `1`, `10`, and `100`. In other words, generate the following DataFrame:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/FUCGiKP.png)

# %%
df = wine_reviews.loc[[0,1,10,100], ["country", "province", "region_1", "region_2"]]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# ## 7.
#
# Create a variable `df` containing the `country` and `variety` columns of the first 100 records.
#
# Hint: you may use `loc` or `iloc`. When working on the answer this question and the several of the ones that follow, keep the following "gotcha" described in the tutorial:
#
# > `iloc` uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.
# `loc`, meanwhile, indexes inclusively.
#
# > This is particularly confusing when the DataFrame index is a simple numerical list, e.g. `0,...,1000`. In this case `df.iloc[0:1000]` will return 1000 entries, while `df.loc[0:1000]` return 1001 of them! To get 1000 elements using `loc`, you will need to go one lower and ask for `df.iloc[0:999]`.

# %%
df = wine_reviews.loc[0:99, ["country", "variety"]]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# 2         US                Pinot Gris
# 3         US                  Riesling
# 4         US                Pinot Noir
# ..       ...                       ...
# 95    France                     Gamay
# 96    France                     Gamay
# 97        US                  Riesling
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 8.
#
# Create a DataFrame `italian_wines` containing reviews of wines made in `Italy`. Hint: `reviews.country` equals what?

# %%
italian_wines = wine_reviews.loc[wine_reviews["country"] == "Italy"]
italian_wines
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %% [markdown]
# ## 9.
#
# Create a DataFrame `top_oceania_wines` containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

# %%
top_oceania_wines = wine_reviews.loc[(wine_reviews.points >= 95) & (wine_reviews.country.isin(["Australia", "New Zealand"]))]
top_oceania_wines
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# 348       Australia  Deep mahogany. Dried fig and black tea on the ...
# 349       Australia  RunRig is always complex, and the 2012 doesn't...
# 356       Australia  Dusty, firm, powerful: just a few apt descript...
# 360       Australia  Bacon and tapenade elements merge easily on th...
# 365       Australia  The Taylor family selected Clare Valley for it...
# 14354     Australia  This wine's concentrated dark fruit shows in t...
# 16538     Australia  Rich, dense and intense, this is a big, muscul...
# 28573     Australia  Astralis has become one of Australia's top col...
# 34502     Australia  This prodigious wine showcases Barossa's abili...
# 34506     Australia  If Standish's Relic is the feminine side of Sh...
# ...
